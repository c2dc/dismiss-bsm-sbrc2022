# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
import time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# modelo
m = 1
# tamanho da janela deslizante
n = 3
# ataque
at = 1
veremiPath = "/content/drive/MyDrive/dataset/veremi"
t2Path = "/veremiWithT2"
simcsvPath = '/simulationscsv'
window = "/window"+str(n)+"v2"
model = "/model"+str(m)
preprocessing = "/preprocessing"
atk = "/atk"+str(at)

os.chdir(veremiPath+t2Path+window+model+atk)
os.listdir()
# Out:
# ['withrssi', 'onlydist']

# %%
# WithRSSI
# transformar os demais ataques em label 0
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import MultiLabelBinarizer
os.chdir(veremiPath+t2Path+window+model+'/allscenarios2')
allsc2 = pd.read_csv('allsc2.csv', index_col=0)
allsc2.iloc[:, -1].loc[allsc2.iloc[:, -1] != at] = 0
# allsc2.iloc[:, -1].unique()
# split data and label
data = allsc2.iloc[:, 0:-1].values
classes = allsc2.iloc[:, -1].values
# multilabel binarize
lb = preprocessing.LabelBinarizer()
lb.fit(classes)
lb.classes_
classes = lb.transform(classes)
classes = MultiLabelBinarizer().fit_transform(classes)
# split test and train
data_train, data_test, classes_train, classes_test = train_test_split(data, classes, test_size=0.2, random_state=1)
print('data_train', data_train.shape)
print('data_test', data_test.shape)
print('classes_train', classes_train.shape)
print('classes_test', classes_test.shape)
clTrain = lb.inverse_transform(classes_train)
clTest = lb.inverse_transform(classes_test)
# classes_train
clTrain = pd.Series(clTrain)
qtd0 = len(clTrain.loc[clTrain == 0])
qtdat = len(clTrain.loc[clTrain == at])
print('classes_train binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# classes_test
clTest = pd.Series(clTest)
qtd0 = len(clTest.loc[clTest == 0])
qtdat = len(clTest.loc[clTest == at])
print('classes_test binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# Out:
# data_train (14817733, 6)
# data_test (3704434, 6)
# classes_train (14817733, 2)
# classes_test (3704434, 2)
# classes_train binary distribution:
# qtd 0 =  14239836 | 96.0999634694457 %
# qtd 1 =  577897 | 3.9000365305543028 %
# classes_test binary distribution:
# qtd 0 =  3559982 | 96.10056489061486 %
# qtd 1 =  144452 | 3.8994351093851316 %

# %%
# with RSSI
# modelo rede neural
layer1 = keras.Input(shape=(data_train.shape[1],))
layer2 = keras.layers.Dense(7, activation="relu")(layer1)
layer3 = keras.layers.Dense(7, activation="relu")(layer2)
output = keras.layers.Dense(2, activation="softmax")(layer3)
modelrelu = keras.Model(inputs=layer1, outputs=output, name='model'+str(m)+'relu')
print(modelrelu.summary())
# keras.utils.plot_model(model, "my_model.png", show_shapes=True)
modelrelu.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(),
             tf.keras.metrics.Recall(class_id=1)],
)
start_time = time.time()
early_stopping = EarlyStopping(
    monitor="loss",
    patience=3,
    min_delta=1e-4,
    restore_best_weights=True
)
modelrelu.fit(
    data_train,
    classes_train,
    epochs=200,
    batch_size=1000,
    callbacks=[early_stopping]
)
print('Done in ', "{:.2f}".format(time.time() - start_time)+' sec', sep='')
modelrelu.save(veremiPath+t2Path+window+model+atk+'/withrssi')
# Out:
# Model: "model1relu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 6)]               0
#
#  dense_24 (Dense)            (None, 7)                 49
#
#  dense_25 (Dense)            (None, 7)                 56
#
#  dense_26 (Dense)            (None, 2)                 16
#
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 14818/14818 [==============================] - 38s 2ms/step - loss: 0.2498 - categorical_accuracy: 0.9670 - recall_2: 0.2593
# Epoch 2/200
# 14818/14818 [==============================] - 36s 2ms/step - loss: 0.0880 - categorical_accuracy: 0.9702 - recall_2: 0.3599
# Epoch 3/200
# 14818/14818 [==============================] - 37s 2ms/step - loss: 0.0869 - categorical_accuracy: 0.9701 - recall_2: 0.3645
# Epoch 4/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0870 - categorical_accuracy: 0.9703 - recall_2: 0.3655
# Epoch 5/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0885 - categorical_accuracy: 0.9704 - recall_2: 0.3648
# Epoch 6/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0868 - categorical_accuracy: 0.9703 - recall_2: 0.3681
# Epoch 7/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0855 - categorical_accuracy: 0.9703 - recall_2: 0.3696
# Epoch 8/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0841 - categorical_accuracy: 0.9704 - recall_2: 0.3718
# Epoch 9/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0831 - categorical_accuracy: 0.9705 - recall_2: 0.3733
# Epoch 10/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0829 - categorical_accuracy: 0.9704 - recall_2: 0.3720
# Epoch 11/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0813 - categorical_accuracy: 0.9706 - recall_2: 0.3765
# Epoch 12/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0802 - categorical_accuracy: 0.9706 - recall_2: 0.3752
# Epoch 13/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0798 - categorical_accuracy: 0.9706 - recall_2: 0.3685
# Epoch 14/200
# 14818/14818 [==============================] - 39s 3ms/step - loss: 0.0802 - categorical_accuracy: 0.9706 - recall_2: 0.3643
# Epoch 15/200
# 14818/14818 [==============================] - 35s 2ms/step - loss: 0.0800 - categorical_accuracy: 0.9705 - recall_2: 0.3618
# Epoch 16/200
# 14818/14818 [==============================] - 37s 2ms/step - loss: 0.0806 - categorical_accuracy: 0.9707 - recall_2: 0.3624
# Done in 574.47 sec
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/dataset/veremi/veremiWithT2/window3v2/model1/atk1/withrssi/assets

# %%
# with RSSI
# metrics
modelrelu = keras.models.load_model(veremiPath+t2Path+window+model+atk+'/withrssi')
predictsrelu = modelrelu.predict(data_test)
clTest = lb.inverse_transform(classes_test)
os.chdir(veremiPath+t2Path+window+model+atk+'/withrssi')
# Best threshold
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(clTest, predictsrelu[:, 1], pos_label=at)
# convert to f score
np.seterr(divide='ignore', invalid='ignore')
fscore = (2 * precision * recall) / (precision + recall)
np.nan_to_num(fscore, copy=False)
# locate the index of the largest f score
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
print("-"*70)
# Classification Report
from sklearn.metrics import classification_report
clTest = lb.inverse_transform(classes_test)
predrelu = lb.inverse_transform(predictsrelu, threshold=thresholds[ix])
print('Classification Report for md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi')
print(classification_report(clTest, predrelu, target_names=['class all', 'class '+str(at)], digits=3, zero_division=0))
print("-"*70)
# Confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(clTest, predrelu, labels=lb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lb.classes_)
disp.plot()
# plt.title('md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.savefig('md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.show()
print("-"*70)
# Precision-Recall curve
from sklearn.metrics import PrecisionRecallDisplay
PrecisionRecallDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
# plt.title('PR curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
no_skill = len(clTest[clTest==1]) / len(clTest)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', color="grey", label='No Skill')
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best threshold')
plt.legend()
plt.savefig('PRcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.show()
print("-"*70)
# ROC curve
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
# plt.title('ROC curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.plot([0, 1], [0, 1], color="grey", lw=1, linestyle="--")
plt.savefig('ROCcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.show()
# Out:
# Best Threshold=0.083224, F-Score=0.545
# ----------------------------------------------------------------------
# Classification Report for md1w3at1withrssi
#               precision    recall  f1-score   support
#
#    class all      0.985     0.970     0.978   3559982
#      class 1      0.469     0.648     0.544    144452
#
#     accuracy                          0.958   3704434
#    macro avg      0.727     0.809     0.761   3704434
# weighted avg      0.965     0.958     0.961   3704434
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------

# %%
# retirar o RSSI
os.chdir(veremiPath+t2Path+window+model+'/allscenarios2')
allsc2 = pd.read_csv('allsc2.csv', index_col=0)
allsc2 = allsc2[['0', '2', '4', '6']]
# transformar os demais ataques em label 0
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import MultiLabelBinarizer
allsc2.iloc[:, -1].loc[allsc2.iloc[:, -1] != at] = 0
# allsc2.iloc[:, -1].unique()
# split data and label
data = allsc2.iloc[:, 0:-1].values
classes = allsc2.iloc[:, -1].values
# multilabel binarize
lb = preprocessing.LabelBinarizer()
lb.fit(classes)
lb.classes_
classes = lb.transform(classes)
classes = MultiLabelBinarizer().fit_transform(classes)
# split test and train
data_train, data_test, classes_train, classes_test = train_test_split(data, classes, test_size=0.2, random_state=1)
print('data_train', data_train.shape)
print('data_test', data_test.shape)
print('classes_train', classes_train.shape)
print('classes_test', classes_test.shape)
clTrain = lb.inverse_transform(classes_train)
clTest = lb.inverse_transform(classes_test)
# classes_train
clTrain = pd.Series(clTrain)
qtd0 = len(clTrain.loc[clTrain == 0])
qtdat = len(clTrain.loc[clTrain == at])
print('classes_train binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# classes_test
clTest = pd.Series(clTest)
qtd0 = len(clTest.loc[clTest == 0])
qtdat = len(clTest.loc[clTest == at])
print('classes_test binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# Out:
# data_train (14817733, 3)
# data_test (3704434, 3)
# classes_train (14817733, 2)
# classes_test (3704434, 2)
# classes_train binary distribution:
# qtd 0 =  14239836 | 96.0999634694457 %
# qtd 1 =  577897 | 3.9000365305543028 %
# classes_test binary distribution:
# qtd 0 =  3559982 | 96.10056489061486 %
# qtd 1 =  144452 | 3.8994351093851316 %

# %%
# onlydist
# modelo rede neural
layer1 = keras.Input(shape=(data_train.shape[1],))
layer2 = keras.layers.Dense(7, activation="relu")(layer1)
layer3 = keras.layers.Dense(7, activation="relu")(layer2)
output = keras.layers.Dense(2, activation="softmax")(layer3)
modelrelu = keras.Model(inputs=layer1, outputs=output, name='model'+str(m)+'relu')
print(modelrelu.summary())
# keras.utils.plot_model(model, "my_model.png", show_shapes=True)
modelrelu.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),
             tf.keras.metrics.FalseNegatives()],
)
start_time = time.time()
early_stopping = EarlyStopping(
    monitor="loss",
    patience=3,
    min_delta=1e-4,
    restore_best_weights=True
)
modelrelu.fit(
    data_train,
    classes_train,
    epochs=200,
    batch_size=1000,
    callbacks=[early_stopping]
)
print('Done in ', "{:.2f}".format(time.time() - start_time)+' sec', sep='')
modelrelu.save(veremiPath+t2Path+window+model+atk+'/onlydist')
# Out:
# Model: "model1relu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 3)]               0
#
#  dense_6 (Dense)             (None, 7)                 28
#
#  dense_7 (Dense)             (None, 7)                 56
#
#  dense_8 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 100
# Trainable params: 100
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.2596 - binary_accuracy: 0.9668 - false_negatives_2: 492361.0000
# Epoch 2/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0851 - binary_accuracy: 0.9694 - false_negatives_2: 453305.0000
# Epoch 3/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0891 - binary_accuracy: 0.9692 - false_negatives_2: 456208.0000
# Epoch 4/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0889 - binary_accuracy: 0.9694 - false_negatives_2: 453533.0000
# Epoch 5/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0849 - binary_accuracy: 0.9699 - false_negatives_2: 445282.0000
# Epoch 6/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0839 - binary_accuracy: 0.9700 - false_negatives_2: 443897.0000
# Epoch 7/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0827 - binary_accuracy: 0.9703 - false_negatives_2: 440505.0000
# Epoch 8/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0818 - binary_accuracy: 0.9705 - false_negatives_2: 437277.0000
# Epoch 9/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0803 - binary_accuracy: 0.9706 - false_negatives_2: 435362.0000
# Epoch 10/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0788 - binary_accuracy: 0.9708 - false_negatives_2: 432831.0000
# Epoch 11/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0781 - binary_accuracy: 0.9708 - false_negatives_2: 432891.0000
# Epoch 12/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0770 - binary_accuracy: 0.9709 - false_negatives_2: 431293.0000
# Epoch 13/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0768 - binary_accuracy: 0.9709 - false_negatives_2: 431441.0000
# Epoch 14/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0767 - binary_accuracy: 0.9709 - false_negatives_2: 431131.0000
# Epoch 15/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0761 - binary_accuracy: 0.9710 - false_negatives_2: 429569.0000
# Epoch 16/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0757 - binary_accuracy: 0.9711 - false_negatives_2: 428360.0000
# Epoch 17/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0769 - binary_accuracy: 0.9710 - false_negatives_2: 429868.0000
# Epoch 18/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0774 - binary_accuracy: 0.9709 - false_negatives_2: 431287.0000
# Epoch 19/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.0780 - binary_accuracy: 0.9709 - false_negatives_2: 430779.0000
# Done in 515.40 sec
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/dataset/veremi/veremiWithT2/window3v2/model1/atk1/onlydist/assets

# %%
# Only dist, without RSSI
# metrics
modelrelu = keras.models.load_model(veremiPath+t2Path+window+model+atk+'/onlydist')
predictsrelu = modelrelu.predict(data_test)
clTest = lb.inverse_transform(classes_test)
os.chdir(veremiPath+t2Path+window+model+atk+'/onlydist')
# Best threshold
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(clTest, predictsrelu[:, 1], pos_label=at)
# convert to f score
np.seterr(divide='ignore', invalid='ignore')
fscore = (2 * precision * recall) / (precision + recall)
np.nan_to_num(fscore, copy=False)
# locate the index of the largest f score
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
print("-"*70)
# Classification Report
from sklearn.metrics import classification_report
predictsrelu = modelrelu.predict(data_test)
clTest = lb.inverse_transform(classes_test)
predrelu = lb.inverse_transform(predictsrelu, threshold=thresholds[ix])
print('Classification Report for md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist')
print(classification_report(clTest, predrelu, target_names=['class all', 'class '+str(at)], digits=3, zero_division=0))
print("-"*70)
# Confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
predrelu = lb.inverse_transform(predictsrelu, threshold=thresholds[ix])
cm = confusion_matrix(clTest, predrelu, labels=lb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lb.classes_)
disp.plot()
plt.title('md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.savefig('md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.show()
print("-"*70)
# Precision-Recall curve
from sklearn.metrics import PrecisionRecallDisplay
PrecisionRecallDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
plt.title('PR curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
no_skill = len(clTest[clTest==1]) / len(clTest)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', color="grey", label='No Skill')
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best threshold')
plt.legend()
plt.savefig('PRcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.show()
print("-"*70)
# ROC curve
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
plt.title('ROC curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.plot([0, 1], [0, 1], color="grey", lw=1, linestyle="--")
plt.savefig('ROCcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.show()
# Out:
# Best Threshold=0.323689, F-Score=0.538
# ----------------------------------------------------------------------
# Classification Report for md1w3at1onlydist
#               precision    recall  f1-score   support
#
#    class all      0.977     0.992     0.985   3559982
#      class 1      0.700     0.436     0.537    144452
#
#     accuracy                          0.971   3704434
#    macro avg      0.839     0.714     0.761   3704434
# weighted avg      0.967     0.971     0.967   3704434
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
