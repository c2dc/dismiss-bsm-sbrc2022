# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
import time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# modelo
m = 1
# tamanho da janela deslizante
n = 3
# ataque
at = 8
veremiPath = "/content/drive/MyDrive/dataset/veremi"
t2Path = "/veremiWithT2"
simcsvPath = '/simulationscsv'
window = "/window"+str(n)+"v2"
model = "/model"+str(m)
preprocessing = "/preprocessing"
atk = "/atk"+str(at)

os.chdir(veremiPath+t2Path+window+model+atk)
os.listdir()
# Out:
# ['withrssi', 'onlydist']

# %%
# WithRSSI
# transformar os demais ataques em label 0
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import MultiLabelBinarizer
os.chdir(veremiPath+t2Path+window+model+'/allscenarios2')
allsc2 = pd.read_csv('allsc2.csv', index_col=0)
allsc2.iloc[:, -1].loc[allsc2.iloc[:, -1] != at] = 0
# allsc2.iloc[:, -1].unique()
# split data and label
data = allsc2.iloc[:, 0:-1].values
classes = allsc2.iloc[:, -1].values
# multilabel binarize
lb = preprocessing.LabelBinarizer()
lb.fit(classes)
lb.classes_
classes = lb.transform(classes)
classes = MultiLabelBinarizer().fit_transform(classes)
# split test and train
data_train, data_test, classes_train, classes_test = train_test_split(data, classes, test_size=0.2, random_state=1)
print('data_train', data_train.shape)
print('data_test', data_test.shape)
print('classes_train', classes_train.shape)
print('classes_test', classes_test.shape)
clTrain = lb.inverse_transform(classes_train)
clTest = lb.inverse_transform(classes_test)
# classes_train
clTrain = pd.Series(clTrain)
qtd0 = len(clTrain.loc[clTrain == 0])
qtdat = len(clTrain.loc[clTrain == at])
print('classes_train binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# classes_test
clTest = pd.Series(clTest)
qtd0 = len(clTest.loc[clTest == 0])
qtdat = len(clTest.loc[clTest == at])
print('classes_test binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# Out:
# data_train (14817733, 6)
# data_test (3704434, 6)
# classes_train (14817733, 2)
# classes_test (3704434, 2)
# classes_train binary distribution:
# qtd 0 =  14237092 | 96.08144511714444 %
# qtd 8 =  580641 | 3.9185548828555623 %
# classes_test binary distribution:
# qtd 0 =  3559276 | 96.08150664851904 %
# qtd 8 =  145158 | 3.918493351480955 %

# %%
# with RSSI
# modelo rede neural
layer1 = keras.Input(shape=(data_train.shape[1],))
layer2 = keras.layers.Dense(7, activation="relu")(layer1)
layer3 = keras.layers.Dense(7, activation="relu")(layer2)
output = keras.layers.Dense(2, activation="softmax")(layer3)
modelrelu = keras.Model(inputs=layer1, outputs=output, name='model'+str(m)+'relu')
print(modelrelu.summary())
# keras.utils.plot_model(model, "my_model.png", show_shapes=True)
modelrelu.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(),
             tf.keras.metrics.Recall(class_id=1)],
)
start_time = time.time()
early_stopping = EarlyStopping(
    monitor="loss",
    patience=3,
    min_delta=1e-4,
    restore_best_weights=True
)
modelrelu.fit(
    data_train,
    classes_train,
    epochs=200,
    batch_size=1000,
    callbacks=[early_stopping]
)
print('Done in ', "{:.2f}".format(time.time() - start_time)+' sec', sep='')
modelrelu.save(veremiPath+t2Path+window+model+atk+'/withrssi')
# Out:
# Model: "model1relu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 6)]               0
#
#  dense (Dense)               (None, 7)                 49
#
#  dense_1 (Dense)             (None, 7)                 56
#
#  dense_2 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 14818/14818 [==============================] - 26s 2ms/step - loss: 1.2968 - categorical_accuracy: 0.9602 - recall: 5.1667e-04
# Epoch 2/200
# 14818/14818 [==============================] - 24s 2ms/step - loss: 0.1896 - categorical_accuracy: 0.9605 - recall: 1.3778e-05
# Epoch 3/200
# 14818/14818 [==============================] - 25s 2ms/step - loss: 0.1774 - categorical_accuracy: 0.9605 - recall: 0.0000e+00
# Epoch 4/200
# 14818/14818 [==============================] - 24s 2ms/step - loss: 0.1647 - categorical_accuracy: 0.9605 - recall: 2.5834e-05
# Epoch 5/200
# 14818/14818 [==============================] - 25s 2ms/step - loss: 0.1320 - categorical_accuracy: 0.9604 - recall: 0.0172
# Epoch 6/200
# 14818/14818 [==============================] - 24s 2ms/step - loss: 0.1192 - categorical_accuracy: 0.9607 - recall: 7.2334e-04
# Epoch 7/200
# 14818/14818 [==============================] - 25s 2ms/step - loss: 0.1151 - categorical_accuracy: 0.9608 - recall: 9.8167e-05
# Epoch 8/200
# 14818/14818 [==============================] - 24s 2ms/step - loss: 0.1127 - categorical_accuracy: 0.9608 - recall: 0.0033
# Epoch 9/200
# 14818/14818 [==============================] - 24s 2ms/step - loss: 0.1094 - categorical_accuracy: 0.9608 - recall: 0.0172
# Epoch 10/200
# 14818/14818 [==============================] - 24s 2ms/step - loss: 0.1072 - categorical_accuracy: 0.9608 - recall: 1.7222e-05
# Epoch 11/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1066 - categorical_accuracy: 0.9608 - recall: 0.0000e+00
# Epoch 12/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.1063 - categorical_accuracy: 0.9608 - recall: 5.1667e-06
# Epoch 13/200
# 14818/14818 [==============================] - 26s 2ms/step - loss: 0.1060 - categorical_accuracy: 0.9608 - recall: 1.0333e-05
# Epoch 14/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.1056 - categorical_accuracy: 0.9608 - recall: 6.8889e-06
# Epoch 15/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.1052 - categorical_accuracy: 0.9608 - recall: 3.4445e-06
# Epoch 16/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.1047 - categorical_accuracy: 0.9608 - recall: 5.3389e-05
# Epoch 17/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.1038 - categorical_accuracy: 0.9608 - recall: 1.3950e-04
# Epoch 18/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1033 - categorical_accuracy: 0.9608 - recall: 0.0010
# Epoch 19/200
# 14818/14818 [==============================] - 26s 2ms/step - loss: 0.1031 - categorical_accuracy: 0.9609 - recall: 0.0055
# Epoch 20/200
# 14818/14818 [==============================] - 26s 2ms/step - loss: 0.1029 - categorical_accuracy: 0.9609 - recall: 0.0115
# Epoch 21/200
# 14818/14818 [==============================] - 26s 2ms/step - loss: 0.1028 - categorical_accuracy: 0.9610 - recall: 0.0190
# Epoch 22/200
# 14818/14818 [==============================] - 26s 2ms/step - loss: 0.1027 - categorical_accuracy: 0.9609 - recall: 0.0225
# Epoch 23/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.1026 - categorical_accuracy: 0.9610 - recall: 0.0274
# Epoch 24/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1024 - categorical_accuracy: 0.9610 - recall: 0.0310
# Epoch 25/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1020 - categorical_accuracy: 0.9610 - recall: 0.0387
# Epoch 26/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1015 - categorical_accuracy: 0.9610 - recall: 0.0406
# Epoch 27/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1013 - categorical_accuracy: 0.9610 - recall: 0.0523
# Epoch 28/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1013 - categorical_accuracy: 0.9611 - recall: 0.0589
# Epoch 29/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1012 - categorical_accuracy: 0.9611 - recall: 0.0614
# Epoch 30/200
# 14818/14818 [==============================] - 27s 2ms/step - loss: 0.1012 - categorical_accuracy: 0.9611 - recall: 0.0623
# Done in 792.65 sec
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/dataset/veremi/veremiWithT2/window3v2/model1/atk8/withrssi/assets

# %%
# with RSSI
# metrics
modelrelu = keras.models.load_model(veremiPath+t2Path+window+model+atk+'/withrssi')
predictsrelu = modelrelu.predict(data_test)
clTest = lb.inverse_transform(classes_test)
os.chdir(veremiPath+t2Path+window+model+atk+'/withrssi')
# Best threshold
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(clTest, predictsrelu[:, 1], pos_label=at)
# convert to f score
np.seterr(divide='ignore', invalid='ignore')
fscore = (2 * precision * recall) / (precision + recall)
np.nan_to_num(fscore, copy=False)
# locate the index of the largest f score
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
print("-"*70)
# Classification Report
from sklearn.metrics import classification_report
clTest = lb.inverse_transform(classes_test)
predrelu = lb.inverse_transform(predictsrelu, threshold=thresholds[ix])
print('Classification Report for md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi')
print(classification_report(clTest, predrelu, target_names=['class all', 'class '+str(at)], digits=3, zero_division=0))
print("-"*70)
# Confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(clTest, predrelu, labels=lb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lb.classes_)
disp.plot()
# plt.title('md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.savefig('md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.show()
print("-"*70)
# Precision-Recall curve
from sklearn.metrics import PrecisionRecallDisplay
PrecisionRecallDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
# plt.title('PR curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
no_skill = len(clTest[clTest==1]) / len(clTest)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', color="grey", label='No Skill')
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best threshold')
plt.legend()
plt.savefig('PRcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.show()
print("-"*70)
# ROC curve
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
# plt.title('ROC curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.plot([0, 1], [0, 1], color="grey", lw=1, linestyle="--")
plt.savefig('ROCcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'withrssi'+'.pdf')
plt.show()
# Out:
# Best Threshold=0.091938, F-Score=0.419
# ----------------------------------------------------------------------
# Classification Report for md1w3at8withrssi
#               precision    recall  f1-score   support
#
#    class all      0.983     0.950     0.966   3559276
#      class 8      0.325     0.589     0.419    145158
#
#     accuracy                          0.936   3704434
#    macro avg      0.654     0.770     0.693   3704434
# weighted avg      0.957     0.936     0.945   3704434
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------

# %%
# retirar o RSSI
os.chdir(veremiPath+t2Path+window+model+'/allscenarios2')
allsc2 = pd.read_csv('allsc2.csv', index_col=0)
allsc2 = allsc2[['0', '2', '4', '6']]
# transformar os demais ataques em label 0
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import MultiLabelBinarizer
allsc2.iloc[:, -1].loc[allsc2.iloc[:, -1] != at] = 0
# allsc2.iloc[:, -1].unique()
# split data and label
data = allsc2.iloc[:, 0:-1].values
classes = allsc2.iloc[:, -1].values
# multilabel binarize
lb = preprocessing.LabelBinarizer()
lb.fit(classes)
lb.classes_
classes = lb.transform(classes)
classes = MultiLabelBinarizer().fit_transform(classes)
# split test and train
data_train, data_test, classes_train, classes_test = train_test_split(data, classes, test_size=0.2, random_state=1)
print('data_train', data_train.shape)
print('data_test', data_test.shape)
print('classes_train', classes_train.shape)
print('classes_test', classes_test.shape)
clTrain = lb.inverse_transform(classes_train)
clTest = lb.inverse_transform(classes_test)
# classes_train
clTrain = pd.Series(clTrain)
qtd0 = len(clTrain.loc[clTrain == 0])
qtdat = len(clTrain.loc[clTrain == at])
print('classes_train binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# classes_test
clTest = pd.Series(clTest)
qtd0 = len(clTest.loc[clTest == 0])
qtdat = len(clTest.loc[clTest == at])
print('classes_test binary distribution:')
print('qtd 0 = ', qtd0, '|', qtd0*100/(qtd0+qtdat), '%')
print('qtd '+str(at)+' = ', qtdat, '|', qtdat*100/(qtd0+qtdat), '%')
# Out:
# data_train (14817733, 3)
# data_test (3704434, 3)
# classes_train (14817733, 2)
# classes_test (3704434, 2)
# classes_train binary distribution:
# qtd 0 =  14237092 | 96.08144511714444 %
# qtd 8 =  580641 | 3.9185548828555623 %
# classes_test binary distribution:
# qtd 0 =  3559276 | 96.08150664851904 %
# qtd 8 =  145158 | 3.918493351480955 %

# %%
# onlydist
# modelo rede neural
layer1 = keras.Input(shape=(data_train.shape[1],))
layer2 = keras.layers.Dense(7, activation="relu")(layer1)
layer3 = keras.layers.Dense(7, activation="relu")(layer2)
output = keras.layers.Dense(2, activation="softmax")(layer3)
modelrelu = keras.Model(inputs=layer1, outputs=output, name='model'+str(m)+'relu')
print(modelrelu.summary())
# keras.utils.plot_model(model, "my_model.png", show_shapes=True)
modelrelu.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),
             tf.keras.metrics.FalseNegatives()],
)
start_time = time.time()
early_stopping = EarlyStopping(
    monitor="loss",
    patience=3,
    min_delta=1e-4,
    restore_best_weights=True
)
modelrelu.fit(
    data_train,
    classes_train,
    epochs=200,
    batch_size=1000,
    callbacks=[early_stopping]
)
print('Done in ', "{:.2f}".format(time.time() - start_time)+' sec', sep='')
modelrelu.save(veremiPath+t2Path+window+model+atk+'/onlydist')
# Out:
# Model: "model1relu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3)]               0
#
#  dense_3 (Dense)             (None, 7)                 28
#
#  dense_4 (Dense)             (None, 7)                 56
#
#  dense_5 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 100
# Trainable params: 100
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.2186 - binary_accuracy: 0.9604 - false_negatives: 586678.0000
# Epoch 2/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1381 - binary_accuracy: 0.9604 - false_negatives: 587180.0000
# Epoch 3/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1191 - binary_accuracy: 0.9604 - false_negatives: 586652.0000
# Epoch 4/200
# 14818/14818 [==============================] - 28s 2ms/step - loss: 0.1095 - binary_accuracy: 0.9607 - false_negatives: 582678.0000
# Epoch 5/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1078 - binary_accuracy: 0.9608 - false_negatives: 580813.0000
# Epoch 6/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1073 - binary_accuracy: 0.9608 - false_negatives: 580135.0000
# Epoch 7/200
# 14818/14818 [==============================] - 30s 2ms/step - loss: 0.1069 - binary_accuracy: 0.9609 - false_negatives: 579565.0000
# Epoch 8/200
# 14818/14818 [==============================] - 30s 2ms/step - loss: 0.1061 - binary_accuracy: 0.9609 - false_negatives: 579138.0000
# Epoch 9/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1046 - binary_accuracy: 0.9609 - false_negatives: 578636.0000
# Epoch 10/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1044 - binary_accuracy: 0.9610 - false_negatives: 578248.0000
# Epoch 11/200
# 14818/14818 [==============================] - 31s 2ms/step - loss: 0.1041 - binary_accuracy: 0.9610 - false_negatives: 578010.0000
# Epoch 12/200
# 14818/14818 [==============================] - 30s 2ms/step - loss: 0.1039 - binary_accuracy: 0.9609 - false_negatives: 579323.0000
# Epoch 13/200
# 14818/14818 [==============================] - 30s 2ms/step - loss: 0.1038 - binary_accuracy: 0.9609 - false_negatives: 579811.0000
# Epoch 14/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1037 - binary_accuracy: 0.9609 - false_negatives: 579954.0000
# Epoch 15/200
# 14818/14818 [==============================] - 36s 2ms/step - loss: 0.1037 - binary_accuracy: 0.9609 - false_negatives: 579598.0000
# Epoch 16/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1036 - binary_accuracy: 0.9609 - false_negatives: 579505.0000
# Epoch 17/200
# 14818/14818 [==============================] - 30s 2ms/step - loss: 0.1036 - binary_accuracy: 0.9609 - false_negatives: 579146.0000
# Epoch 18/200
# 14818/14818 [==============================] - 31s 2ms/step - loss: 0.1035 - binary_accuracy: 0.9609 - false_negatives: 579216.0000
# Epoch 19/200
# 14818/14818 [==============================] - 33s 2ms/step - loss: 0.1034 - binary_accuracy: 0.9609 - false_negatives: 579032.0000
# Epoch 20/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1033 - binary_accuracy: 0.9610 - false_negatives: 578307.0000
# Epoch 21/200
# 14818/14818 [==============================] - 30s 2ms/step - loss: 0.1032 - binary_accuracy: 0.9610 - false_negatives: 578006.0000
# Epoch 22/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1032 - binary_accuracy: 0.9610 - false_negatives: 577467.0000
# Epoch 23/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1031 - binary_accuracy: 0.9611 - false_negatives: 576984.0000
# Epoch 24/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1030 - binary_accuracy: 0.9611 - false_negatives: 576955.0000
# Epoch 25/200
# 14818/14818 [==============================] - 32s 2ms/step - loss: 0.1030 - binary_accuracy: 0.9611 - false_negatives: 576881.0000
# Epoch 26/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1029 - binary_accuracy: 0.9611 - false_negatives: 577056.0000
# Epoch 27/200
# 14818/14818 [==============================] - 30s 2ms/step - loss: 0.1029 - binary_accuracy: 0.9611 - false_negatives: 576913.0000
# Epoch 28/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1030 - binary_accuracy: 0.9611 - false_negatives: 576626.0000
# Epoch 29/200
# 14818/14818 [==============================] - 29s 2ms/step - loss: 0.1029 - binary_accuracy: 0.9611 - false_negatives: 576717.0000
# Done in 864.44 sec
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/dataset/veremi/veremiWithT2/window3v2/model1/atk8/onlydist/assets

# %%
# Only dist, without RSSI
# metrics
modelrelu = keras.models.load_model(veremiPath+t2Path+window+model+atk+'/onlydist')
predictsrelu = modelrelu.predict(data_test)
clTest = lb.inverse_transform(classes_test)
os.chdir(veremiPath+t2Path+window+model+atk+'/onlydist')
# Best threshold
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(clTest, predictsrelu[:, 1], pos_label=at)
# convert to f score
np.seterr(divide='ignore', invalid='ignore')
fscore = (2 * precision * recall) / (precision + recall)
np.nan_to_num(fscore, copy=False)
# locate the index of the largest f score
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
print("-"*70)
# Classification Report
from sklearn.metrics import classification_report
predictsrelu = modelrelu.predict(data_test)
clTest = lb.inverse_transform(classes_test)
predrelu = lb.inverse_transform(predictsrelu, threshold=thresholds[ix])
print('Classification Report for md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist')
print(classification_report(clTest, predrelu, target_names=['class all', 'class '+str(at)], digits=3, zero_division=0))
print("-"*70)
# Confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
predrelu = lb.inverse_transform(predictsrelu, threshold=thresholds[ix])
cm = confusion_matrix(clTest, predrelu, labels=lb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lb.classes_)
disp.plot()
plt.title('md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.savefig('md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.show()
print("-"*70)
# Precision-Recall curve
from sklearn.metrics import PrecisionRecallDisplay
PrecisionRecallDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
plt.title('PR curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
no_skill = len(clTest[clTest==1]) / len(clTest)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', color="grey", label='No Skill')
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best threshold')
plt.legend()
plt.savefig('PRcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.show()
print("-"*70)
# ROC curve
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(clTest, predictsrelu[:, 1], pos_label=at)
plt.title('ROC curve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.plot([0, 1], [0, 1], color="grey", lw=1, linestyle="--")
plt.savefig('ROCcurve '+'md'+str(m)+'w'+str(n)+'at'+str(at)+'onlydist'+'.pdf')
plt.show()
# Out:
# Best Threshold=0.045818, F-Score=0.403
# ----------------------------------------------------------------------
# Classification Report for md1w3at8onlydist
#               precision    recall  f1-score   support
#
#    class all      0.984     0.941     0.962   3559276
#      class 8      0.299     0.616     0.403    145158
#
#     accuracy                          0.928   3704434
#    macro avg      0.641     0.779     0.682   3704434
# weighted avg      0.957     0.928     0.940   3704434
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
